# %% [markdown]
# In this session we are going to generate combined ranks and get mean and standard deviation of the combined ranks of covid, flu, hiv.

# %%
import pandas as pd
# fnames = ["extended_analyze_semantics_cov_bilstm_512.txt",
#           "extended_analyze_semantics_flu_h1_bilstm_512.txt",
#           "extended_analyze_semantics_hiv_bilstm_512.txt"]
# cov_df, flu_df, hiv_df = tuple(map(lambda x: pd.read_csv(x, sep='\t'), fnames))
# cov_df = pd.read_csv("extended_analyze_semantics_covrbd_bilstm_512.txt", sep='\t')

# for the starting index of amino sequence, follow the biology rule (1-based index)
cov_df = pd.read_csv("ranked_extended_analyze_semantics_cov_bilstm_512.txt", sep='\t')
print(cov_df[cov_df['pos'] ==445]['wt'])
# Out:
# 4171     K
# 4172     K
# 4173     K
# 4174     K
# 4175     K
# 4176     K
# 4177     K
# 4178     K
# 20443    K
# 20444    K
# 20445    K
# 20446    K
# 20447    K
# 20448    K
# 20449    K
# 20450    K
# 20451    K
# 20452    K
# 20453    K
# Name: wt, dtype: object

# %%
"""Make rank of 'prob', 'change', 'codon indep', 'codon dep'.
"""
rank_names = ['grammar rank', 'sem change rank', 'indep rank', 'dep rank']
score_names = ['prob', 'change', 'codon indep', 'codon dep']
rank_names_hiv = ['grammar rank', 'sem change rank', 'dep rank']
score_names_hiv = ['prob', 'change', 'codon dep']
def rank_helper(df, rank_names, score_names):
    df[rank_names] = df[score_names].rank(method="min", ascending=False)

rank_helper(cov_df, rank_names, score_names)
# rank_helper(flu_df, rank_names, score_names)
# rank_helper(hiv_df, rank_names_hiv, score_names_hiv)
# # hiv doesn't have 'indep rank'
# hiv_df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 10
#       7 def rank_helper(df, rank_names, score_names):
#       8     df[rank_names] = df[score_names].rank(method="min", ascending=False)
# ---> 10 rank_helper(cov_df, rank_names, score_names)
#      11 # rank_helper(flu_df, rank_names, score_names)
#      12 # rank_helper(hiv_df, rank_names_hiv, score_names_hiv)
#      13 # # hiv doesn't have 'indep rank'
#      14 # hiv_df
#
# Cell In[3], line 8, in rank_helper(df, rank_names, score_names)
#       7 def rank_helper(df, rank_names, score_names):
# ----> 8     df[rank_names] = df[score_names].rank(method="min", ascending=False)
#
# File ~/.conda/envs/conda-mut/lib/python3.11/site-packages/pandas/core/frame.py:3899, in DataFrame.__getitem__(self, key)
#    3897     if is_iterator(key):
#    3898         key = list(key)
# -> 3899     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3901 # take() does not accept boolean indexers
#    3902 if getattr(indexer, "dtype", None) == bool:
#
# File ~/.conda/envs/conda-mut/lib/python3.11/site-packages/pandas/core/indexes/base.py:6115, in Index._get_indexer_strict(self, key, axis_name)
#    6112 else:
#    6113     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 6115 self._raise_if_missing(keyarr, indexer, axis_name)
#    6117 keyarr = self.take(indexer)
#    6118 if isinstance(key, Index):
#    6119     # GH 42790 - Preserve name from an Index
#
# File ~/.conda/envs/conda-mut/lib/python3.11/site-packages/pandas/core/indexes/base.py:6179, in Index._raise_if_missing(self, key, indexer, axis_name)
#    6176     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    6178 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 6179 raise KeyError(f"{not_found} not in index")
#
# KeyError: "['codon dep'] not in index"

# %%
from itertools import combinations
"""make combined rank"""
def combined_rank_helper(df, rank_names, num):
    for combined_rank in combinations(rank_names, num):
        df['+'.join(combined_rank) + " rank"] = (df[list(combined_rank)].sum(axis=1)).rank(method='min')
combined_rank_helper(cov_df, rank_names, 1)
combined_rank_helper(cov_df, rank_names, 2)
combined_rank_helper(cov_df, rank_names, 3)

combined_rank_helper(flu_df, rank_names, 1)
combined_rank_helper(flu_df, rank_names, 2)
combined_rank_helper(flu_df, rank_names, 3)

combined_rank_helper(hiv_df, rank_names_hiv, 1)
combined_rank_helper(hiv_df, rank_names_hiv, 2)
combined_rank_helper(hiv_df, rank_names_hiv, 3)
cov_df
# Out:
#        pos wt mut          prob  change  is_viable  is_escape   codon indep  \
# 0        2  F   A  4.983475e-05  2056.0      False      False  3.527765e-10
# 1        2  F   C  2.952611e-05  2502.0      False      False  6.883835e-06
# 2        2  F   D  1.466931e-07  2048.0      False      False  5.212324e-11
# 3        2  F   E  5.211668e-06  2256.0      False      False  7.534191e-16
# 4        3  V   A  2.152248e-06  1576.0      False      False  5.124971e-05
# ...    ... ..  ..           ...     ...        ...        ...           ...
# 24163    2  F   S  2.906836e-05  1823.0      False      False  5.124976e-05
# 24164    2  F   T  7.235685e-06  1750.0      False      False  3.880541e-10
# 24165    2  F   V  7.380600e-04  1897.0      False      False  6.883935e-06
# 24166    2  F   W  1.973972e-07  1649.0      False      False  4.738233e-11
# 24167    2  F   Y  1.955664e-04  1540.0      False      False  7.572219e-06
#
#           codon dep  grammar rank  ...  sem change rank+dep rank rank  \
# 0      8.253441e-06        3219.0  ...                        20951.0
# 1      1.530512e-03        4129.0  ...                        10476.0
# 2      3.542369e-07       15909.0  ...                        23371.0
# 3      3.943546e-09        7840.0  ...                        23776.0
# 4      4.840870e-03        9960.0  ...                        13358.0
# ...             ...           ...  ...                            ...
# 24163  7.310778e-03        4168.0  ...                        11628.0
# 24164  1.922392e-06        7104.0  ...                        22993.0
# 24165  1.077892e-03         523.0  ...                        15026.0
# 24166  9.587666e-07       15314.0  ...                        23442.0
# 24167  8.766995e-04        1475.0  ...                        16569.0
#
#        indep rank+dep rank rank  grammar rank+sem change rank+indep rank rank  \
# 0                       15860.0                                       15826.0
# 1                        5838.0                                        7612.0
# 2                       20399.0                                       22923.0
# 3                       24050.0                                       21457.0
# 4                        2216.0                                       11761.0
# ...                         ...                                           ...
# 24163                    1728.0                                        7069.0
# 24164                   17473.0                                       18871.0
# 24165                    6257.0                                        7511.0
# 24166                   19824.0                                       23217.0
# 24167                    6113.0                                        8580.0
#
#        grammar rank+sem change rank+dep rank rank  \
# 0                                         13869.0
# 1                                          5583.0
# 2                                         23065.0
# 3                                         21364.0
# 4                                         11456.0
# ...                                           ...
# 24163                                      6314.0
# 24164                                     19517.0
# 24165                                      6018.0
# 24166                                     22993.0
# 24167                                      7783.0
#
#        grammar rank+indep rank+dep rank rank  \
# 0                                    11163.0
# 1                                     3798.0
# 2                                    20463.0
# 3                                    20374.0
# 4                                     3431.0
# ...                                      ...
# 24163                                 1368.0
# 24164                                14256.0
# 24165                                 2663.0
# 24166                                19848.0
# 24167                                 2967.0
#
#        sem change rank+indep rank+dep rank rank  grammar rank rank  \
# 0                                       20475.0             3219.0
# 1                                        8832.0             4129.0
# 2                                       23075.0            15909.0
# 3                                       23957.0             7840.0
# 4                                        7704.0             9960.0
# ...                                         ...                ...
# 24163                                    6765.0             4168.0
# 24164                                   22084.0             7104.0
# 24165                                   11027.0              523.0
# 24166                                   23159.0            15314.0
# 24167                                   11627.0             1475.0
#
#        sem change rank rank  indep rank rank  dep rank rank
# 0                   20998.0          17196.0        14307.0
# 1                   18245.0           7354.0         4323.0
# 2                   21112.0          19616.0        20448.0
# 3                   19798.0          24110.0        23786.0
# 4                   23005.0           2616.0         2236.0
# ...                     ...              ...            ...
# 24163               22170.0           2557.0         1525.0
# 24164               22443.0          16688.0        17718.0
# 24165               21877.0           7182.0         4982.0
# 24166               22778.0          19887.0        19059.0
# 24167               23082.0           6523.0         5488.0
#
# [24168 rows x 27 columns]

# %%
def mean_std_helper(df, name):
    return f'mean and std of {name} is\t{df[name].mean()},\t{df[name].std()}'

def escape_filter(df):
    return df[df['is_escape'] == True]
cov_df_escape, flu_df_escape, hiv_df_escape = map(escape_filter, (cov_df, flu_df, hiv_df))


for df, file_name in ((cov_df_escape, "cov_escape_result.txt"), (flu_df_escape, "flu_escape_result.txt"), (hiv_df_escape, 'hiv_escape_result.txt')):
    with open(file_name, 'w') as file:
        for text in map(lambda x: mean_std_helper(df, x), filter(lambda string: "rank rank" in string, df.columns)):
            print(text)
            file.write(text + '\n')
# Out:
# mean and std of grammar rank+sem change rank rank is	3757.8947368421054,	2644.9654670028162
# mean and std of grammar rank+indep rank rank is	2613.3684210526317,	2324.1966404312293
# mean and std of grammar rank+dep rank rank is	2730.7894736842104,	2453.287739135822
# mean and std of sem change rank+indep rank rank is	3206.3684210526317,	2980.913808633675
# mean and std of sem change rank+dep rank rank is	3312.1052631578946,	2950.0416738061485
# mean and std of indep rank+dep rank rank is	3081.7368421052633,	2097.696007054334
# mean and std of grammar rank+sem change rank+indep rank rank is	1854.7894736842106,	1399.6249330504136
# mean and std of grammar rank+sem change rank+dep rank rank is	1930.0,	1496.5355176391756
# mean and std of grammar rank+indep rank+dep rank rank is	2463.6315789473683,	2091.076575741318
# mean and std of sem change rank+indep rank+dep rank rank is	2443.2631578947367,	2012.9164535873829
# mean and std of grammar rank rank is	4916.894736842105,	3784.9298671726015
# mean and std of sem change rank rank is	8786.684210526315,	4965.693507038866
# mean and std of indep rank rank is	3043.842105263158,	1982.7207811253788
# mean and std of dep rank rank is	3330.2105263157896,	2229.4224857310114
# mean and std of grammar rank+sem change rank rank is	2058.205882352941,	1914.859297431348
# mean and std of grammar rank+indep rank rank is	3189.929411764706,	2414.1186211289014
# mean and std of grammar rank+dep rank rank is	3540.5529411764705,	2555.9632027144585
# mean and std of sem change rank+indep rank rank is	3789.764705882353,	2717.1918507489563
# mean and std of sem change rank+dep rank rank is	4192.170588235294,	2895.9568673977265
# mean and std of indep rank+dep rank rank is	5043.764705882353,	3089.5752648366006
# mean and std of grammar rank+sem change rank+indep rank rank is	2550.4470588235295,	2173.2032883933352
# mean and std of grammar rank+sem change rank+dep rank rank is	2864.3,	2354.112415433265
# mean and std of grammar rank+indep rank+dep rank rank is	3943.141176470588,	2764.367942579841
# mean and std of sem change rank+indep rank+dep rank rank is	4404.211764705882,	2991.035599067714
# mean and std of grammar rank rank is	2255.029411764706,	1971.1109276422414
# mean and std of sem change rank rank is	3872.1470588235293,	2656.129467378521
# mean and std of indep rank rank is	4823.888235294117,	3035.615971217842
# mean and std of dep rank rank is	5391.235294117647,	3197.4776454920698
# mean and std of grammar rank+sem change rank rank is	4633.88198757764,	3736.4614884588364
# mean and std of grammar rank+dep rank rank is	5039.372670807454,	3437.951168246642
# mean and std of sem change rank+dep rank rank is	4587.0496894409935,	3576.5271070572817
# mean and std of grammar rank+sem change rank+dep rank rank is	4498.409937888198,	3575.9016266391645
# mean and std of grammar rank rank is	5147.180124223602,	3505.294092312724
# mean and std of sem change rank rank is	5108.248447204969,	3544.1831358421923
# mean and std of dep rank rank is	5394.913043478261,	3646.069123712729

# %%
cov_df_escape.to_csv("cov_escape.csv")
flu_df_escape.to_csv("flu_escape.csv")
hiv_df_escape.to_csv("hiv_escape.csv")
